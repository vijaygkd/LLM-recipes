# %% [markdown]
# # Document AI - Question Answering
#
# * Multimodal system to answer questions about documents.
# * Document AI models use text input and image document input. They also use OCR model to generate word list and bounding boxes which can be used as inputs. These are packed together with the model in the input processor.
#
# Ref:
# - [Huggingface Document QA tutorial](https://huggingface.co/docs/transformers/en/tasks/document_question_answering)
# - [LayoutLMv2 / v3](https://huggingface.co/docs/transformers/en/model_doc/layoutlmv2)
#     - Requires Google `pytesseract` for OCR engine

# %% [markdown]
# # Inference

# %%
# model_checkpoint = 'microsoft/layoutlmv3-base'
model_checkpoint = 'microsoft/layoutlmv2-base-uncased'

# %% [markdown]
# ### Input preprocessing

# %%
from transformers import LayoutLMv3Processor
from PIL import Image

model_checkpoint = 'microsoft/layoutlmv3-base'

processor = LayoutLMv3Processor.from_pretrained(model_checkpoint)

# %%
from transformers import LayoutLMv2Processor
from PIL import Image

model_checkpoint = 'microsoft/layoutlmv2-base-uncased'
processor = LayoutLMv2Processor.from_pretrained(model_checkpoint)
# Out:
# preprocessor_config.json:   0%|          | 0.00/135 [00:00<?, ?B/s]

# %%
image = Image.open(
    "artifacts/lab.png"
).convert("RGB")

question = "What are the tests in this report?"
encoding = processor(image, question, return_tensors="pt")
print(encoding.keys())
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask', 'bbox', 'image'])
# Out:
# ---------------------------------------------------------------------------
# InvalidVersion                            Traceback (most recent call last)
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pytesseract/pytesseract.py:395, in get_tesseract_version()
#     394 try:
# --> 395     version = parse(str_version)
#     396     assert version >= TESSERACT_MIN_VERSION
#
# File ~/.local/lib/python3.8/site-packages/packaging/version.py:54, in parse(version)
#      46 """Parse the given version string.
#      47
#      48 >>> parse('1.0.dev1')
#    (...)
#      52 :raises InvalidVersion: When the version string is not a valid version.
#      53 """
# ---> 54 return Version(version)
#
# File ~/.local/lib/python3.8/site-packages/packaging/version.py:200, in Version.__init__(self, version)
#     199 if not match:
# --> 200     raise InvalidVersion(f"Invalid version: '{version}'")
#     202 # Store the parsed out pieces of the version
#
# InvalidVersion: Invalid version: '38/lib/libtiff.so.5:'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[5], line 6
#       5 question = "What are the tests in this report?"
# ----> 6 encoding = processor(image, question, return_tensors="pt")
#       7 print(encoding.keys())
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/transformers/models/layoutlmv3/processing_layoutlmv3.py:115, in LayoutLMv3Processor.__call__(self, images, text, text_pair, boxes, word_labels, add_special_tokens, padding, truncation, max_length, stride, pad_to_multiple_of, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, return_tensors, **kwargs)
#     114 # first, apply the image processor
# --> 115 features = self.image_processor(images=images, return_tensors=return_tensors)
#     117 # second, apply the tokenizer
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/transformers/image_processing_utils.py:551, in BaseImageProcessor.__call__(self, images, **kwargs)
#     550 """Preprocess an image or a batch of images."""
# --> 551 return self.preprocess(images, **kwargs)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/transformers/models/layoutlmv3/image_processing_layoutlmv3.py:356, in LayoutLMv3ImageProcessor.preprocess(self, images, do_resize, size, resample, do_rescale, rescale_factor, do_normalize, image_mean, image_std, apply_ocr, ocr_lang, tesseract_config, return_tensors, data_format, input_data_format, **kwargs)
#     355 for image in images:
# --> 356     words, boxes = apply_tesseract(image, ocr_lang, tesseract_config, input_data_format=input_data_format)
#     357     words_batch.append(words)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/transformers/models/layoutlmv3/image_processing_layoutlmv3.py:70, in apply_tesseract(image, lang, tesseract_config, input_data_format)
#      69 image_width, image_height = pil_image.size
# ---> 70 data = pytesseract.image_to_data(pil_image, lang=lang, output_type="dict", config=tesseract_config)
#      71 words, left, top, width, height = data["text"], data["left"], data["top"], data["width"], data["height"]
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pytesseract/pytesseract.py:514, in image_to_data(image, lang, config, nice, output_type, timeout, pandas_config)
#     509 """
#     510 Returns string containing box boundaries, confidences,
#     511 and other information. Requires Tesseract 3.05+
#     512 """
# --> 514 if get_tesseract_version() < TESSERACT_MIN_VERSION:
#     515     raise TSVNotSupported()
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pytesseract/pytesseract.py:145, in run_once.<locals>.wrapper(*args, **kwargs)
#     144 if wrapper._result is wrapper:
# --> 145     wrapper._result = func(*args, **kwargs)
#     146 return wrapper._result
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pytesseract/pytesseract.py:398, in get_tesseract_version()
#     397 except (AssertionError, InvalidVersion):
# --> 398     raise SystemExit(f'Invalid tesseract version: "{raw_version}"')
#     400 return version
#
# SystemExit: Invalid tesseract version: "tesseract: /anaconda/envs/azureml_py38/lib/libtiff.so.5: no version information available (required by /lib/x86_64-linux-gnu/liblept.so.5)
# tesseract 4.1.1
#  leptonica-1.79.0
#   libgif 5.1.4 : libjpeg 8d (libjpeg-turbo 2.0.3) : libpng 1.6.37 : libtiff 4.1.0 : zlib 1.2.13 : libwebp 0.6.1 : libopenjp2 2.3.1
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE
#  Found libarchive 3.4.0 zlib/1.2.11 liblzma/5.2.4 bz2lib/1.0.8 liblz4/1.9.2 libzstd/1.4.4
# "
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2095, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2092 if exception_only:
#    2093     stb = ['An exception has occurred, use %tb to see '
#    2094            'the full traceback.\n']
# -> 2095     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2096                                                      value))
#    2097 else:
#    2098     try:
#    2099         # Exception classes can customise their traceback - we
#    2100         # use this in IPython.parallel for exceptions occurring
#    2101         # in the engines. This should return a list of strings.
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:696, in ListTB.get_exception_only(self, etype, value)
#     688 def get_exception_only(self, etype, value):
#     689     """Only print the exception type and message, without a traceback.
#     690
#     691     Parameters
#    (...)
#     694     value : exception value
#     695     """
# --> 696     return ListTB.structured_traceback(self, etype, value)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:559, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     556     chained_exc_ids.add(id(exception[1]))
#     557     chained_exceptions_tb_offset = 0
#     558     out_list = (
# --> 559         self.structured_traceback(
#     560             etype,
#     561             evalue,
#     562             (etb, chained_exc_ids),  # type: ignore
#     563             chained_exceptions_tb_offset,
#     564             context,
#     565         )
#     566         + chained_exception_message
#     567         + out_list)
#     569 return out_list
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1396, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1394 else:
#    1395     self.tb = etb
# -> 1396 return FormattedTB.structured_traceback(
#    1397     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1398 )
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1287, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1284 mode = self.mode
#    1285 if mode in self.verbose_modes:
#    1286     # Verbose modes need a full traceback
# -> 1287     return VerboseTB.structured_traceback(
#    1288         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1289     )
#    1290 elif mode == 'Minimal':
#    1291     return ListTB.get_exception_only(self, etype, value)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1140, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1131 def structured_traceback(
#    1132     self,
#    1133     etype: type,
#    (...)
#    1137     number_of_lines_of_context: int = 5,
#    1138 ):
#    1139     """Return a nice text document describing the traceback."""
# -> 1140     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1141                                                            tb_offset)
#    1143     colors = self.Colors  # just a shorthand + quicker name lookup
#    1144     colorsnormal = colors.Normal  # used a lot
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1030, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1027 assert isinstance(tb_offset, int)
#    1028 head = self.prepare_header(str(etype), self.long_header)
#    1029 records = (
# -> 1030     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1031 )
#    1033 frames = []
#    1034 skipped = 0
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1098, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1096 while cf is not None:
#    1097     try:
# -> 1098         mod = inspect.getmodule(cf.tb_frame)
#    1099         if mod is not None:
#    1100             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'

# %%
import pytesseract

text = pytesseract.image_to_string(image, lang = 'eng')
print(text)

data = pytesseract.image_to_data(image, lang='eng') #, config=tesseract_config)
# Out:
# Results Compare result trends
#
#
#
#
#
# Cholesterol Viewtrends Triglycerides View trends
# Normal range: below <=200 mg/dL Normal range: below <=150 mg/dL
#
# Value 205 Value 54
# LDL Calculated Viewtrends = HDL View trends
# Normal range: below <100 mg/dL Normal range: above >=40.0 mg/dL
#
# Value 133 Value 61.6
# ---------------------------------------------------------------------------
# InvalidVersion                            Traceback (most recent call last)
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pytesseract/pytesseract.py:395, in get_tesseract_version()
#     394 try:
# --> 395     version = parse(str_version)
#     396     assert version >= TESSERACT_MIN_VERSION
#
# File ~/.local/lib/python3.8/site-packages/packaging/version.py:54, in parse(version)
#      46 """Parse the given version string.
#      47
#      48 >>> parse('1.0.dev1')
#    (...)
#      52 :raises InvalidVersion: When the version string is not a valid version.
#      53 """
# ---> 54 return Version(version)
#
# File ~/.local/lib/python3.8/site-packages/packaging/version.py:200, in Version.__init__(self, version)
#     199 if not match:
# --> 200     raise InvalidVersion(f"Invalid version: '{version}'")
#     202 # Store the parsed out pieces of the version
#
# InvalidVersion: Invalid version: '38/lib/libtiff.so.5:'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[6], line 6
#       4 print(text)
# ----> 6 data = pytesseract.image_to_data(image, lang='eng') #, config=tesseract_config)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pytesseract/pytesseract.py:514, in image_to_data(image, lang, config, nice, output_type, timeout, pandas_config)
#     509 """
#     510 Returns string containing box boundaries, confidences,
#     511 and other information. Requires Tesseract 3.05+
#     512 """
# --> 514 if get_tesseract_version() < TESSERACT_MIN_VERSION:
#     515     raise TSVNotSupported()
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pytesseract/pytesseract.py:145, in run_once.<locals>.wrapper(*args, **kwargs)
#     144 if wrapper._result is wrapper:
# --> 145     wrapper._result = func(*args, **kwargs)
#     146 return wrapper._result
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pytesseract/pytesseract.py:398, in get_tesseract_version()
#     397 except (AssertionError, InvalidVersion):
# --> 398     raise SystemExit(f'Invalid tesseract version: "{raw_version}"')
#     400 return version
#
# SystemExit: Invalid tesseract version: "tesseract: /anaconda/envs/azureml_py38/lib/libtiff.so.5: no version information available (required by /lib/x86_64-linux-gnu/liblept.so.5)
# tesseract 4.1.1
#  leptonica-1.79.0
#   libgif 5.1.4 : libjpeg 8d (libjpeg-turbo 2.0.3) : libpng 1.6.37 : libtiff 4.1.0 : zlib 1.2.13 : libwebp 0.6.1 : libopenjp2 2.3.1
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE
#  Found libarchive 3.4.0 zlib/1.2.11 liblzma/5.2.4 bz2lib/1.0.8 liblz4/1.9.2 libzstd/1.4.4
# "
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2095, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2092 if exception_only:
#    2093     stb = ['An exception has occurred, use %tb to see '
#    2094            'the full traceback.\n']
# -> 2095     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2096                                                      value))
#    2097 else:
#    2098     try:
#    2099         # Exception classes can customise their traceback - we
#    2100         # use this in IPython.parallel for exceptions occurring
#    2101         # in the engines. This should return a list of strings.
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:696, in ListTB.get_exception_only(self, etype, value)
#     688 def get_exception_only(self, etype, value):
#     689     """Only print the exception type and message, without a traceback.
#     690
#     691     Parameters
#    (...)
#     694     value : exception value
#     695     """
# --> 696     return ListTB.structured_traceback(self, etype, value)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:559, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     556     chained_exc_ids.add(id(exception[1]))
#     557     chained_exceptions_tb_offset = 0
#     558     out_list = (
# --> 559         self.structured_traceback(
#     560             etype,
#     561             evalue,
#     562             (etb, chained_exc_ids),  # type: ignore
#     563             chained_exceptions_tb_offset,
#     564             context,
#     565         )
#     566         + chained_exception_message
#     567         + out_list)
#     569 return out_list
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1396, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1394 else:
#    1395     self.tb = etb
# -> 1396 return FormattedTB.structured_traceback(
#    1397     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1398 )
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1287, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1284 mode = self.mode
#    1285 if mode in self.verbose_modes:
#    1286     # Verbose modes need a full traceback
# -> 1287     return VerboseTB.structured_traceback(
#    1288         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1289     )
#    1290 elif mode == 'Minimal':
#    1291     return ListTB.get_exception_only(self, etype, value)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1140, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1131 def structured_traceback(
#    1132     self,
#    1133     etype: type,
#    (...)
#    1137     number_of_lines_of_context: int = 5,
#    1138 ):
#    1139     """Return a nice text document describing the traceback."""
# -> 1140     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1141                                                            tb_offset)
#    1143     colors = self.Colors  # just a shorthand + quicker name lookup
#    1144     colorsnormal = colors.Normal  # used a lot
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1030, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1027 assert isinstance(tb_offset, int)
#    1028 head = self.prepare_header(str(etype), self.long_header)
#    1029 records = (
# -> 1030     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1031 )
#    1033 frames = []
#    1034 skipped = 0
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1098, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1096 while cf is not None:
#    1097     try:
# -> 1098         mod = inspect.getmodule(cf.tb_frame)
#    1099         if mod is not None:
#    1100             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'

# %%
pytesseract.get_tesseract_version()
# Out:
# ---------------------------------------------------------------------------
# InvalidVersion                            Traceback (most recent call last)
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pytesseract/pytesseract.py:395, in get_tesseract_version()
#     394 try:
# --> 395     version = parse(str_version)
#     396     assert version >= TESSERACT_MIN_VERSION
#
# File ~/.local/lib/python3.8/site-packages/packaging/version.py:54, in parse(version)
#      46 """Parse the given version string.
#      47
#      48 >>> parse('1.0.dev1')
#    (...)
#      52 :raises InvalidVersion: When the version string is not a valid version.
#      53 """
# ---> 54 return Version(version)
#
# File ~/.local/lib/python3.8/site-packages/packaging/version.py:200, in Version.__init__(self, version)
#     199 if not match:
# --> 200     raise InvalidVersion(f"Invalid version: '{version}'")
#     202 # Store the parsed out pieces of the version
#
# InvalidVersion: Invalid version: '38/lib/libtiff.so.5:'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[6], line 1
# ----> 1 pytesseract.get_tesseract_version()
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pytesseract/pytesseract.py:145, in run_once.<locals>.wrapper(*args, **kwargs)
#     144 if wrapper._result is wrapper:
# --> 145     wrapper._result = func(*args, **kwargs)
#     146 return wrapper._result
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/pytesseract/pytesseract.py:398, in get_tesseract_version()
#     397 except (AssertionError, InvalidVersion):
# --> 398     raise SystemExit(f'Invalid tesseract version: "{raw_version}"')
#     400 return version
#
# SystemExit: Invalid tesseract version: "tesseract: /anaconda/envs/azureml_py38/lib/libtiff.so.5: no version information available (required by /lib/x86_64-linux-gnu/liblept.so.5)
# tesseract 4.1.1
#  leptonica-1.79.0
#   libgif 5.1.4 : libjpeg 8d (libjpeg-turbo 2.0.3) : libpng 1.6.37 : libtiff 4.1.0 : zlib 1.2.13 : libwebp 0.6.1 : libopenjp2 2.3.1
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE
#  Found libarchive 3.4.0 zlib/1.2.11 liblzma/5.2.4 bz2lib/1.0.8 liblz4/1.9.2 libzstd/1.4.4
# "
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2095, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2092 if exception_only:
#    2093     stb = ['An exception has occurred, use %tb to see '
#    2094            'the full traceback.\n']
# -> 2095     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2096                                                      value))
#    2097 else:
#    2098     try:
#    2099         # Exception classes can customise their traceback - we
#    2100         # use this in IPython.parallel for exceptions occurring
#    2101         # in the engines. This should return a list of strings.
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:696, in ListTB.get_exception_only(self, etype, value)
#     688 def get_exception_only(self, etype, value):
#     689     """Only print the exception type and message, without a traceback.
#     690
#     691     Parameters
#    (...)
#     694     value : exception value
#     695     """
# --> 696     return ListTB.structured_traceback(self, etype, value)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:559, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     556     chained_exc_ids.add(id(exception[1]))
#     557     chained_exceptions_tb_offset = 0
#     558     out_list = (
# --> 559         self.structured_traceback(
#     560             etype,
#     561             evalue,
#     562             (etb, chained_exc_ids),  # type: ignore
#     563             chained_exceptions_tb_offset,
#     564             context,
#     565         )
#     566         + chained_exception_message
#     567         + out_list)
#     569 return out_list
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1396, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1394 else:
#    1395     self.tb = etb
# -> 1396 return FormattedTB.structured_traceback(
#    1397     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1398 )
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1287, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1284 mode = self.mode
#    1285 if mode in self.verbose_modes:
#    1286     # Verbose modes need a full traceback
# -> 1287     return VerboseTB.structured_traceback(
#    1288         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1289     )
#    1290 elif mode == 'Minimal':
#    1291     return ListTB.get_exception_only(self, etype, value)
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1140, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1131 def structured_traceback(
#    1132     self,
#    1133     etype: type,
#    (...)
#    1137     number_of_lines_of_context: int = 5,
#    1138 ):
#    1139     """Return a nice text document describing the traceback."""
# -> 1140     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1141                                                            tb_offset)
#    1143     colors = self.Colors  # just a shorthand + quicker name lookup
#    1144     colorsnormal = colors.Normal  # used a lot
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1030, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1027 assert isinstance(tb_offset, int)
#    1028 head = self.prepare_header(str(etype), self.long_header)
#    1029 records = (
# -> 1030     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1031 )
#    1033 frames = []
#    1034 skipped = 0
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/ultratb.py:1098, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1096 while cf is not None:
#    1097     try:
# -> 1098         mod = inspect.getmodule(cf.tb_frame)
#    1099         if mod is not None:
#    1100             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'
